# %%
from dir_reader import DirReader

# %%
reader = DirReader()

# %%
reader.list_programmes()
# Out:
# [{'name': 'programme_2025_12_25',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25',
#   'date': '25/12/2025',
#   'structures_count': 29},
#  {'name': 'programme_2025_06_25',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_06_25',
#   'date': '25/06/2025',
#   'structures_count': 0}]

# %%
reader.list_brigades("programme_2025_12_25", "DGE","DIRECTION_GRANDES ENTREPRISES")
# Out:
# [{'name': 'BV1_DGE',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV1_DGE',
#   'total_files': 98,
#   'xlsx_count': 40,
#   'png_count': 58,
#   'contribuables_count': 40},
#  {'name': 'BV2_DGE',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV2_DGE',
#   'total_files': 102,
#   'xlsx_count': 41,
#   'png_count': 61,
#   'contribuables_count': 41},
#  {'name': 'BV3_DGE',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE',
#   'total_files': 95,
#   'xlsx_count': 39,
#   'png_count': 56,
#   'contribuables_count': 39}]

# %%
reader.list_files_in_brigade("programme_2025_12_25", "DGE","DIRECTION_GRANDES ENTREPRISES", "BV3_DGE")
# Out:
# [{'name': '00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#   'relative_path': 'programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#   'extension': '.xlsx',
#   'size': 74440,
#   'size_formatted': '72.70 KB',
#   'modified_date': '2025-08-14 15:44:58',
#   'file_type': 'xlsx',
#   'ifu': '00000946T'},
#  {'name': '00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE_C.png',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE_C.png',
#   'relative_path': 'programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE_C.png',
# ...

# %%
reader.list_contribuables_in_brigade("programme_2025_12_25", "DGE","DIRECTION_GRANDES ENTREPRISES", "BV3_DGE")
# Out:
# [{'ifu': '00000946T',
#   'xlsx': {'name': '00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#    'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#    'relative_path': 'programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#    'extension': '.xlsx',
#    'size': 74440,
#    'size_formatted': '72.70 KB',
#    'modified_date': '2025-08-14 15:44:58',
#    'file_type': 'xlsx',
#    'ifu': '00000946T'},
#   'chart_png': {'name': '00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE_C.png',
#    'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00000946T_DIRECTION_GRANDES ENTREPRISES_BV3_DGE_C.png',
# ...

# %%
reader.get_contribuable_files("00114537B","programme_2025_12_25", "DGE")
# Out:
# {'ifu': '00114537B',
#  'xlsx': {'name': '00114537B_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00114537B_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#   'relative_path': 'programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00114537B_DIRECTION_GRANDES ENTREPRISES_BV3_DGE.xlsx',
#   'extension': '.xlsx',
#   'size': 71972,
#   'size_formatted': '70.29 KB',
#   'modified_date': '2025-08-14 18:30:41',
#   'file_type': 'xlsx',
#   'ifu': '00114537B'},
#  'chart_png': None,
#  'forecast_png': {'name': '00114537B_DIRECTION_GRANDES ENTREPRISES_BV3_DGE_F.png',
#   'path': 'd:\\DGI\\project\\ANARISK_APP\\anarisk_backend\\programmes\\programme_2025_12_25\\DGE\\DIRECTION_GRANDES ENTREPRISES\\BV3_DGE\\00114537B_DIRECTION_GRANDES ENTREPRISES_BV3_DGE_F.png',
# ...
