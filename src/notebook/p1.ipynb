# %%
import numpy as np
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
merged_df = pd.read_csv("D:/DGI/project/anarisk-r/DCF_PROG_02_02_2026.csv",encoding='latin1' )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_36492\1246847973.py:1: DtypeWarning: Columns (12,17,18,21,26,27,33,34,36,42,47,48,49,59,155,156,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_df = pd.read_csv("D:/DGI/project/anarisk-r/DCF_PROG_02_02_2026.csv",encoding='latin1' )

# %%
merged_df['DATE_DERNIERE_VG']
merged_df['DATE_DERNIERE_VP']
merged_df['DATE_DERNIERE_AVIS']

# %%
merged_df.isnull().sum()
# Out:
# ID_CONTR                      0
# NUM_IFU                     186
# NOM.x                         0
# ENCOMMERC                419695
# NOM_MINEFID               54482
#                           ...
# PREL_SOURCE_ACOMPTE      642505
# RETENUE_SOURCE_IMPUTE    642505
# T̩l̩phone              639563
# Groupe_IFU               639563
# Occurrences_IFU          639563
# Length: 170, dtype: int64
